# %% [markdown]
# <a href="https://colab.research.google.com/github/leejhk/leejhk/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
money = int(input("투입한 돈: "))
price = int(input("물건 값: "))
change = money - price
print("거스름돈: ",change)
coin500s = change // 500 
change = change % 500 
change = change % 100 
change = change % 50 
change = change % 10 
print("100원 동전의 개수: ", coin100s)
print("50원 동전의 개수: ", coin50s)
print("10원 동전의 개수: ", coin10s)


price = int(input("물건 값: "))
change = money - price
coin500s = change // 500 

year = input("오늘의 연도를 입력하시오: ")
month = input("오늘의 월을 입력하시오: ")
date = input("오늘의 일을 입력하시오: ")
print(month+"/", date+"/", year)

import time
now = time.time()
thisYear = int(1970 + now//(365*24*3600))
print("올해는 ",thisYear,"입니다.")
age = int(input("몇 살이신지요? "))
print("2050년에는 ",(age+2050-thisYear),"살 이시군요.")

age = int(input("나이를 입력하시오: "))
if age >= 15: print("이 영화를 보실 수 있습니다. 영화의 가격은 10000원입니다.")
else: print("이 영화를 보실 수 없습니다. 다른 영화를 보시겠어요?")

import turtle
 while answer: command = input("명령을 입력하시오: ") if command == "l" or command == "left": 
t.left(90) t.forward(100) if command == "r" or command == "right": 
t.right(90) t.forward(100)

import turtle
flag = True
t.left(90) t.forward(100) if command == "r" or command == "right": 
t.right(90) t.forward(100) if command == "q" or command == "quit": 
flag = False
